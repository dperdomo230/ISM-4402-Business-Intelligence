# %%
import pandas as pd
Location = r"C:\Users\dperd\OneDrive\Desktop\ISM 4402\datasets\datasets\gradedata.csv"
df = pd.read_csv(Location)
df = df.sort_values(by=['lname','age','grade'],
 ascending=[True, True, True])
df.head(20)
# Out:
#           fname      lname  gender  age  exercise  hours  grade  \
# 1439       Levi    Acevedo    male   14         2      6   63.0
# 1770    Leandra    Acevedo  female   14         1     15   94.4
# 762    Rhiannon    Acevedo  female   15         3     10   72.7
# 819      Athena    Acevedo  female   15         4     12   90.0
# 1458     Cedric    Acevedo    male   19         5     14   98.8
# 1772     Odette     Acosta  female   15         2      6   68.2
# 31        Carol     Acosta  female   16         3     13   85.0
# 896      Kenyon     Acosta    male   16         1     16   93.1
# 784       Orson     Acosta    male   18         4     14   94.4
# 1822    Kendall     Adkins  female   14         1     13   85.7
# 62    Genevieve     Adkins  female   15         1      8   67.3
# 532       Robin     Adkins  female   16         4      4   68.0
# 195      Hector    Aguilar    male   14         1      9   68.8
# 1708      Colin    Aguilar    male   14         5     15   86.0
# ...
