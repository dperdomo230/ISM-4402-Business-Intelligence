# %%
# Load dataset from CSV
import pandas as pd
import numpy as np
Location = r"C:\Users\dperd\OneDrive\Desktop\ISM 4402\datasets\datasets\gradedata.csv"
df = pd.read_csv(Location)
# Random sample of 500 rows from dataframe
df.take(np.random.permutation(len(df))[:500])
# Out:
#         fname       lname  gender  age  exercise  hours  grade  \
# 1012     Alec    Sheppard    male   16         4     13   88.3
# 672    Ciaran         Gay    male   19         4      3   59.3
# 1294  Kaitlin        Chen  female   18         3     12   79.5
# 1304    Cairo    Cardenas    male   14         4     13   85.9
# 849      Mira      Branch  female   17         2     15   91.8
# ...       ...         ...     ...  ...       ...    ...    ...
# 777     Simon  Mclaughlin    male   15         2      8   74.7
# 770     Quail       Lewis  female   15         4      8   69.1
# 1925   Keelie    Valencia  female   17         3      9   84.2
# 1569    David     Rowland    male   16         3     14   91.3
# 1251    Lance        Rush    male   17         4     15   98.5
#
#                                               address
# 1012             92 Courtland Court, Clover, SC 29710
# 672               157 Bridge Street, Corona, NY 11368
# 1294  535 Alderwood Street, Capitol Heights, MD 20743
# 1304            8439 East Queen St., Groton, CT 06340
# 849              433 Airport Dr., Milwaukee, WI 53204
# ...                                               ...
# 777                 3 Evergreen St., Leland, NC 28451
# 770            9047 N. Addison St., Ashland, OH 44805
# 1925        4 Glen Ridge Drive, Shelbyville, TN 37160
# 1569           404 Cleveland Street, Garner, NC 27529
# 1251     661 Central Street, Port Charlotte, FL 33952
#
# [500 rows x 8 columns]
